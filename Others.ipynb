# %%
from torch.distributions import normal
import torch

# %%
x = torch.Tensor([[1,2],[3,4]])

# %%
m = normal.Normal(x, 0.1)

# %%
m
# Out:
# Normal(loc: torch.Size([2, 2]), scale: torch.Size([2, 2]))

# %%
a = m.sample((5,))

# %%
a
# Out:
# tensor([[[1.1799, 2.0784],
#          [2.8817, 4.0973]],
#
#         [[1.0271, 1.9580],
#          [3.0553, 4.0144]],
#
#         [[1.1359, 1.8070],
#          [2.9763, 4.0606]],
#
#         [[0.9979, 2.1031],
#          [2.9931, 4.1643]],
#
#         [[1.0098, 2.0095],
#          [2.9654, 4.1030]]])

# %%
x1 = m.sample((5,)).mean(0)

# %%
x1
# Out:
# tensor([[0.9699, 2.0559],
#         [3.0271, 4.0124]])

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('OneTrainableSigmaProbAct.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))

plt.plot(x,y, label='Loaded from file!')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-9f39f10cbfb3> in <module>
#       9     for row in plots:
#      10         x.append(int(row[0]))
# ---> 11         y.append(int(row[1]))
#      12
#      13 plt.plot(x,y, label='Loaded from file!')
#
# ValueError: invalid literal for int() with base 10: '0.001685028314'

# %%
import plotly
plotly.__version__
# Out:
# '3.9.0'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="whitegrid")

# %%
df = pd.read_csv('OneTrainableSigmaProbAct.csv')

# %%
df.head()
# Out:
#    Sigma Value STL-10  Sigma Value CIFAR-10  Sigma Value CIFAR-100
# 0            0.001685              0.033339               0.007998
# 1           -0.025967              0.028478               0.021529
# 2           -0.027084             -0.012415               0.006505
# 3            0.018536             -0.002112               0.020115
# 4           -0.031598             -0.005952               0.051712

# %%
sns.set(rc={'figure.figsize':(7,5)})
sns.set_style("whitegrid")
ax=sns.lineplot(data=df, palette="tab10", linewidth=1.5, dashes=False)
ax.set(xlabel='Epochs', ylabel='Sigma Value')
ax.figure.savefig("OneTrainableSigma.pdf")

# %%
df = pd.read_csv('LayerwiseSigmaCIFAR10.csv')

# %%
df.head()
# Out:
#     Layer 1   Layer 2   Layer 3   Layer 4   Layer 5   Layer 6   Layer 7  \
# 0  0.974757  0.998838  0.992600  0.998113  0.975152  0.981733  0.943021
# 1  0.941336  0.976811  0.969598  0.984703  0.952499  0.963842  0.908936
# 2  0.879928  0.944223  0.928623  0.964233  0.912130  0.934786  0.879043
# 3  0.823807  0.916760  0.880599  0.932864  0.868376  0.900692  0.852777
# 4  0.772138  0.886777  0.830754  0.900709  0.810483  0.861488  0.835307
#
#     Layer 8   Layer 9  Layer 10  Layer 11  Layer 12  Layer 13
# 0  0.944607  0.952694  0.814217  0.928627  0.902857  0.687119
# 1  0.903745  0.915836  0.736652  0.824575  0.831817  0.525290
# 2  0.860323  0.882118  0.674925  0.721993  0.763187  0.357865
# 3  0.820782  0.852037  0.641332  0.629420  0.697209  0.283124
# 4  0.785082  0.817053  0.591707  0.535641  0.624407  0.235918

# %%
sns.set(rc={'figure.figsize':(9,6)})
sns.set(font_scale=1)
sns.set_style("whitegrid")

# %%
ax=sns.lineplot(data=df, palette="tab10", linewidth=2, dashes=False)
ax.set(xlabel='Epochs', ylabel='Mean Sigma Value')
ax.figure.savefig("LayerWiseSigma.pdf")

# %%
df = pd.read_csv('TestCIFAR100Overfit.csv')

# %%
ax=sns.lineplot(data=df, palette="tab10", linewidth=1.5, dashes=False)
ax.set(xlabel='Epochs', ylabel='Test Accuracy')
ax.figure.savefig("TestAcc.pdf")

# %%
df = pd.read_csv('TrainCIFAR100Overfit.csv')

# %%
ax=sns.lineplot(data=df, palette="tab10", linewidth=1.5, dashes=False)
ax.set(xlabel='Epochs', ylabel='Train Accuracy')
ax.figure.savefig("TrainAcc.pdf")

# %%
df = pd.read_csv('TestCIFAR10Overfit.csv')

# %%
ax=sns.lineplot(data=df, palette="tab10", linewidth=1, dashes=False)
ax.set(xlabel='Epochs', ylabel='Test Accuracy')
ax.figure.savefig("TestAccCIFAR10.pdf")

# %%
df = pd.read_csv('TrainCIFAR10Overfit.csv')

# %%
ax=sns.lineplot(data=df, palette="tab10", linewidth=1, dashes=False)
ax.set(xlabel='Epochs', ylabel='Train Accuracy')
ax.figure.savefig("TrainAccCIFAR10.pdf")
